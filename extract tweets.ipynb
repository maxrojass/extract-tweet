# %%
# Out:
#   File "<ipython-input-8-6070cbf2b152>", line 24
#     def init(self, fetched_tweets_filename)
#                                            ^
# SyntaxError: invalid syntax

# %%
from __future__ import absolute_import, print_function

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
consumer_key=""
consumer_secret=""
access_token=""
access_token_secret=""

class StdOutListener(StreamListener):

    def on_data(self, data):
        print(data)
        return True

    def on_error(self, status):
        print(status)

if __name__ == '__main__':
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    stream = Stream(auth, l)
stream.filter(track=['basketball'])

# %%
import tweepy          
import pandas as pd   
import numpy as np 
import csv
CONSUMER_KEY = ''
CONSUMER_SECRET = ''

ACCESS_TOKEN = '' 
ACCESS_SECRET = ''
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
api = tweepy.API(auth,wait_on_rate_limit=True)
csvFile = open('tweepy_tweets.csv', 'a')
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,count=50,
                           lang="es",q = "lima").items():
    print (tweet.created_at, tweet.text)
csvFile.writerow([tweet.created_at, tweet.text.encode('utf-8')])
tweet.to_csv(tweepy_tweets.csv)
# Out:
# 2018-12-03 15:47:11 RT @elvenadoblanco: Y lo que hizo hoy Roca Rey en Lima fue sublime... y un ejercicio perfecto de libertad. https://t.co/MV5e4nECHR
# 2018-12-03 15:47:03 RT @xafu: INSÓLITO E INEXPLICABLE
# Para la misma encuestadora, Martín Vizcarra es DESAPROBADO con una nota promedio de 09, en todos los prob…
# 2018-12-03 15:47:00 RT @TelemundoUY: El presidente y el canciller uruguayos explicaron que en Perú funcionan libremente los tres poderes
# #HoyEnTelemundo
# https…
# 2018-12-03 15:46:57 @ShawnAccess Lima,Perú https://t.co/pHn4h2S3ta
# 2018-12-03 15:46:53 RT @conciertosperu: Oficial: @Interpol confirmó concierto en Lima y las entradas salen a la venta este jueves 6! 👌
#
# https://t.co/pv1Xx606DL
# 2018-12-03 15:46:52 RT @fernandodavilac: Alianza Lima es grande por su gente
#
# Fase1 - Pintado de Fachada ✔️
# Gracias @AsocBlanquiazul y Gracias a todos por su c…
# 2018-12-03 15:46:50 RT @PiensaPrensa: URUGUAY: "No hemos concedido el pedido de asilo" a Alan García.
#
# ...

# %%
df= (tweet.created_at, tweet.text)

# %%
df.to_csv(tweepy_tweets.csv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-40fd7f1f9cf2> in <module>
# ----> 1 df.to_csv(tweepy_tweets.csv)
#
# AttributeError: 'tuple' object has no attribute 'to_csv'
